# %%
import polars as pl
import pandas as pd
import os 
os.chdir('..')

# %%
df = pl.read_csv("data/raw/data.csv", ignore_errors=True)
df
# Out:
# shape: (2_653_965, 42)
# ┌───────┬──────┬───────┬────────────────┬───┬────────────┬────────────┬────────────┬──────────┐
# │ Trade ┆ Year ┆ Month ┆ Commodity_Code ┆ … ┆ air_cha_mo ┆ ves_cha_mo ┆ cnt_cha_mo ┆ rev_data │
# │ ---   ┆ ---  ┆ ---   ┆ ---            ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ str   ┆ i64  ┆ i64   ┆ i64            ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str      │
# ╞═══════╪══════╪═══════╪════════════════╪═══╪════════════╪════════════╪════════════╪══════════╡
# │ i     ┆ 2009 ┆ 7     ┆ 101100000      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ Y        │
# │ e     ┆ 2009 ┆ 7     ┆ 101100000      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ Y        │
# │ i     ┆ 2009 ┆ 7     ┆ 105110020      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ Y        │
# │ i     ┆ 2009 ┆ 7     ┆ 105940000      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ Y        │
# │ i     ┆ 2009 ┆ 7     ┆ 105990000      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ Y        │
# │ …     ┆ …    ┆ …     ┆ …              ┆ … ┆ …          ┆ …          ┆ …          ┆ …        │
# │ i     ┆ 2024 ┆ 2     ┆ 9810001500     ┆ … ┆ 500        ┆ 0          ┆ 0          ┆ N        │
# │ i     ┆ 2024 ┆ 2     ┆ 9817005000     ┆ … ┆ 0          ┆ 2500       ┆ 2500       ┆ N        │
# │ i     ┆ 2024 ┆ 2     ┆ 9817005000     ┆ … ┆ 0          ┆ 3501       ┆ 3501       ┆ N        │
# │ e     ┆ 2024 ┆ 2     ┆ 9880004000     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ N        │
# │ i     ┆ 2024 ┆ 2     ┆ 9880004000     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ N        │
# └───────┴──────┴───────┴────────────────┴───┴────────────┴────────────┴────────────┴──────────┘

# %%
df.to_pickle(os.getcwd() + "/data/raw" + "/data.pkl", ignore_errors=True)
